# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/4590_Colabs/blob/main/9_MechToBehavior.ipynb)

# %% [markdown]
# # Set 9 — From Mechanism to Behavior: Fear Learning & Amygdala Network
# **Author: Neural Engineering Laboratory, University of Missouri - Gregory Glickert, Khuram Choudhry, Ziao Chen, Satish S. Nair
# > **Theme.** Building on Sets **A–F** (membrane → synapse → motifs → small networks), we now connect **circuit computation** to **behavioral expression** using a two step scaffold:
# > 1) a classroom unit (TeachEngineering) that operationalizes Pavlovian learning in browser based activities;
# > 2) a compact **12 cell lateral amygdala** (LA) network that reproduces acquisition/extinction patterns with the **same training schedule** and the **same analysis kit** used throughout the chapter. [1](https://raw.githubusercontent.com/cyneuro/Chapter_Colabs/main/AmygdalaFearNetworkModel.pdf)
#
# ---
#
# ## **Variable Key & Roadmap**
#
# ### **The "Levers" (Network & Learning Parameters)**
# In this module, we move beyond simple motifs to a functional circuit that expresses behavior. These variables govern how the network "learns" during conditioning and how it suppresses fear during extinction.
#
# | **Variable** | **Definition** | **Unit** | **Instructional Role** |
# | :--- | :--- | :--- | :--- |
# | **`CS_weight`** | Tone (CS) input strength | μS | Represents the sensory drive from the auditory pathways. |
# | **`US_weight`** | Shock (US) input strength | μS | The reinforcing stimulus that drives Hebbian plasticity. |
# | **`Plasticity_Rate`**| Learning Rate | — | Controls how quickly the CS→PN synapses strengthen during pairing. |
# | **`Inhib_Timing`** | PV/SOM Onset Delay | ms | Critical for controlling the **Latency** and **Peak** of the fear response. |
# | **`Fear_Score`** | Behavioral Index | % | A metric derived from PN firing rates to quantify "fear" expression. |
#
# ---
#
# ### **The Roadmap**
# This module bridges the gap between circuit mechanism and Pavlovian behavior using a two-step scaffold.
#
# 1. **[G1. Classroom Unit](https://raw.githubusercontent.com/cyneuro/Chapter_Colabs/main/AmygdalaFearNetworkModel.pptx)** (Activities 1 & 2, slides 12/18/20 — done from the slide deck, not the notebook): Sketch the 10-cell circuit and predict which synapses grow, to make timing rules (CS/US overlap) tangible before touching code.
# 2. **[G2. Amygdala Network](https://colab.research.google.com/github/cyneuro/Fear-Lesson-Plans/blob/master/Lesson-7-12-Cell/12_cell_amygdala_network.ipynb)** (Activity 3, slide 23): Constructing a 12-cell LA microcircuit (PN, PV, SOM) to simulate acquisition and extinction. **G2–G5 below are all sections within this same notebook** — scroll through it rather than expecting separate links.
# 3. **G3. Behavioral Metrics:** Converting raw spikes into a "Fear Score" using the same analysis kit (Baseline, Peak, Latency) used in previous sets.
# 4. **G4. Mini Studies:** Short exercises to test how timing and weights alter behavioral output.
# 5. **G5. Reflection:** Evaluating the transition from **Mechanism → Plasticity → Behavior**.
#
# ---
#
# ## **G0. Orientation**
# *What changes in Set 9?*
# * **We keep the training phases:** Sensitization → Conditioning → Gap → Extinction.
# * **We keep the analysis kit:** Baseline, Peak, Latency, and Area.
# * **We add a behavioral readout:** The **Fear Score**, which allows us to see how microscopic synaptic changes manifest as macroscopic behavior.
#
# **Systems Callout:** Pavlovian learning is a *temporal credit assignment* problem. The brain must "decide" which stimuli are predictive of danger. In this circuit, inhibitory timing (PV/SOM cells) acts as a gatekeeper for that decision.
#
# ---
# ### A Note on This Notebook
# **This completed notebook (with your written analysis and reflections) is the lab deliverable.** Unlike other Sets, the simulation itself runs in a separate linked NEURON Colab rather than inline here — add your own notes and analysis cells throughout as you work through it.

# %% [markdown]
# ## **G1. Classroom Unit: The Logic of Learning**
# *TeachEngineering Activities (Browser-Based)*
#
# Before we build the 12-cell network in NEURON, we must establish the "Rules of the Game." These activities use interactive browser tools to help you operationalize Pavlovian learning without needing any code installation.
#
# ### **Activity A: Wired to Think (Concepts & Vocabulary)**
# * **The Goal:** Differentiate between innate responses and learned associations.
# * **CS Task:** Think of the **CS (Tone)** as a "Neutral Input" and the **US (Shock)** as a "Reinforcing Signal."
# * **Deliverable:** A 1-page sketch showing where these two input streams converge in the **Amygdala**. Identify the Baseline, Peak, and Latency markers on your sketch.
# * **Resource:** [Activity A Handout](https://www.teachengineering.org/curricularunits/view/umo-2952-brain-learning-process-unit)
#
# ### **Activity B: Predict the Response (Algorithmic Logic)**
# * **The Goal:** Define the training schedule: **Sensitization → Conditioning → Extinction**.
# * **CS Task:** If you were writing an "If/Then" statement for this circuit, how would it change *after* the Tone and Shock overlap?
# * **Deliverable:** 3 written predictions. What happens to the PN (Excitatory) output during the "Gap" phase compared to the "Sensitization" phase?
#
# ### **Activity C: Connecting Circuits of Fear (Virtual Lab)**
# * **The Goal:** Use a [Virtual Lab](https://www.teachengineering.org/curricularunits/view/umo-2952-brain-learning-process-unit) to test how small shifts in timing (milliseconds) determine whether the brain "saves" a memory or ignores it.
# * **CS Task:** Observe the "Temporal Credit Assignment." If the Tone ends *before* the Shock begins, does the circuit still learn?
# * **Deliverable:** One screenshot or sketch of your virtual circuit results + a 3-sentence interpretation of how timing affected the output.
#
# ---
#
# ### **Check-in: Transition to the Model**
# Before scrolling down to G2, answer these two questions in your notebook:
# 1. **Timing:** Based on Activity C, what is the "Goldilocks" timing window for the Tone and Shock to create a memory?
# 2. **Open Question:** What is one thing about the "Biological Interneuron" (PV or SOM) that you are curious to test once we move into the code?

# %% [markdown]
# ## **G2. Amygdala Network: Laboratory Exercise**
# *Translating Microcircuit Logic into Behavioral Expression*
#
# In this section, we transition from the browser activities to a biophysically realistic 12-cell microcircuit. To complete this module, you must follow the interactive laboratory guide provided in the presentation below.
#
# #### **Instructions for Students**
# 1.  **Open the Lab Manual:** Download and open the [Amygdala Fear Network Model PPTX](https://raw.githubusercontent.com/cyneuro/Chapter_Colabs/main/AmygdalaFearNetworkModel.pptx) (or the [PDF Version](https://raw.githubusercontent.com/cyneuro/Chapter_Colabs/main/AmygdalaFearNetworkModel.pdf)).
# 2.  **Locate the Simulation Link:** Follow the slides until you reach **Slide 23 (Activity 3)**.
# 3.  **Run the External Code:** Click the Colab link provided on **Slide 23**. This will open the separate "Simulation Engine" notebook containing the 12-cell NEURON code.
# 4.  **Execute & Observe:** Run the simulation in that external notebook to generate your **Rasters** and **Firing Rate Traces**. Keep that tab open as you return here to complete your analysis.
#
# ---
#
# ### **1. The 12-Cell Microcircuit Architecture**
# As explained in the Lab Manual, our network is composed of three "classes" of neurons:
# * **PN (Principal Cells):** The 8 excitatory output neurons that drive fear behavior.
# * **PV (Parvalbumin):** 2 fast-spiking interneurons providing perisomatic "veto" inhibition.
# * **SOM (Somatostatin):** 2 dendritic-targeting interneurons that gate synaptic inputs.
#
# ### **2. The Hebbian Learning Engine**
# The model uses a **Calcium-Controlled Plasticity Rule**. As you run the external code, watch the Rasters closely during the **Conditioning** phase: the simultaneous arrival of the Tone (CS) and Shock (US) triggers the calcium influx necessary to "save" the fear memory.

# %% [markdown]
# ## **G3. Behavioral Results: Analysis of Conditioning**
# *Interpreting Your Simulation Output*
#
# Once you have generated your data in the external NEURON Colab (linked on **Slide 23**), use this section to interpret the results. As a researcher, your goal is to observe how the **"Calcium Hypothesis"** manifests as a physical change in neural firing patterns.
#
# #### **1. Visualizing the Memory Trace**
# Refer to the plots generated by the external simulation for each of the four phases (**Sensitization, Conditioning, Gap, and Extinction**):
#
# * **The Raster Plot:** Each dot represents an action potential (spike). After conditioning, look for the dense "clustering" of spikes during the Tone (CS) window. This cluster is the physical representation of the **Fear Memory Trace**.
# * **The Population Trace:** This shows the integrated firing rate of the **8 Principal Neurons (PN)**. Compare the height of the **Peak** during Sensitization (Phase 1) versus the **Gap Phase** (Phase 3).
#
# #### **2. Identifying Biophysical Markers**
# Use your results to complete the observations required for your lab report:
#
# | **Marker** | **Observation Goal** | **PPT Reference** |
# | :--- | :--- | :--- |
# | **Baseline Shift** | Does the "noise" or background firing change between phases? | Slide 12 |
# | **Peak Response** | Is the firing more intense *after* the Tone-Shock pairing? | Slide 18 |
# | **Latency** | Does the network fire *sooner* after the Tone starts? | Slide 20 |
#
# ---
#
# > ### **Instructor Note: Data Verification**
# > Before moving to the homework, verify that your **Gap Phase** results show a significant increase in PN firing compared to **Sensitization**. If they look identical, check the `Plasticity_Rate` in the external Colab and re-run the simulation.

# %% [markdown]
# ## **G4. Lab Report & Homework: Synthesizing the Fear Circuit**
# *From Mechanism to Behavior*
#
# This section serves as your independent laboratory station. Now that you have observed the 12-cell network in action via the external simulation (linked on **Slide 23**), you will use the "Analysis Kit" concepts from previous modules (Sets A–F) to document the transition from cellular mechanism to behavioral expression.
#
# ### **1. The Data Analysis Kit**
# As a researcher, you are looking for specific changes in the output signals. Use the plots generated in your external NEURON tab to record the following observations:
#
# * **Feature Extraction:** Record the **Baseline, Peak, and Latency** for each of the four training phases.
# * **The Behavioral Index:** Note the **Area Under the Curve** (the total "volume" of firing) during the Tone—this is your primary indicator of how "scared" the network has become.
#
# ### **Homework Assignment (Refer to PPT Slide 26)**
# Complete the following tasks as outlined on **Slide 26** of the [Amygdala Fear Network Model PPTX](https://raw.githubusercontent.com/cyneuro/Chapter_Colabs/main/AmygdalaFearNetworkModel.pptx).
#
# #### **Task A: The Comparison Table**
# Create a table comparing the **Peak** and **Latency** of the PN cells between **Sensitization** (Phase 1) and the **Gap Phase** (Phase 3).
# * **Observation Check:** Did the latency decrease (faster response) after conditioning?
#
# #### **Task B: The "Calcium" Mechanism**
# In your own words, explain how the **CS-US overlap** triggered the plasticity rule.
# * **Check-in:** Based on your readings, why does the memory "save" only when the stimuli are paired, but not when the Tone occurs alone?
#
# #### **Task C: Mini-Study (Timing & Gain)**
# Refer to the "Mechanism of Competition" in your PPT and answer the following:
# 1. **Timing:** If the **Inhib_Timing** (PV/SOM onset) is advanced (made earlier), how does that physically change the PN output?
# 2. **Gain:** If you increase the **PN↔PN recurrent gain**, does the fear response become more robust or more unstable?
#
# > **Deliverable:** Your final submission should include the completed table from Slide 26, your answers to the three tasks above, and a screenshot of your **Gap Phase Raster** and **Population Trace**.
#
# **Make It Your Own (optional, conceptual).** The 12-cell circuit here is deliberately minimal. Ask an AI assistant: *"Given a 12-cell lateral amygdala model with feedforward/feedback inhibition implementing Pavlovian fear conditioning, what is one additional cell type or connection I could add to make the extinction phase more biologically realistic, and what behavioral prediction would it make?"* You won't implement this in code here (the simulation runs in the external Colab), but describe your reasoning below — this is the same kind of design thinking you'd need before extending the actual model.
#
# *Your Answer Here:*

# %% [markdown]
# ## **G5. Reflection & Discussion**
#
# 1. **The Scaffold:** Explain how using the same training schedule and the same analysis kit (Baseline, Peak, Latency) across both the browser activities (G1) and the NEURON model (G2) helped you connect **Mechanism → Plasticity → Behavior**.
# 2. **The Gatekeeper:** In your observations, where did **inhibitory timing** matter most? How did it change the "shape" of the fear response without changing the strength of the Tone input itself?
# 3. **The Engineering Trade-off:** Identify one limitation of using a 12-cell teaching model compared to a full-scale biophysical model of the Amygdala. Conversely, what is one major advantage of this 12-cell model for a student learning these concepts for the first time?

# %% [markdown]
# ## **Practice / Discussion Questions — Set 9: Model → Behavior**
#
# 1. **The Training Loop:** Briefly describe the **CS–US timing** used in the simulation (Sensitization → Conditioning → Gap → Extinction). Why is the "overlap" during the conditioning phase the critical variable for learning?
# 2. **Scaffolding:** How did the browser activities in G1 prepare you for the 12-cell model? Name one specific concept (e.g., timing or stimulus type) that remained consistent across both.
# 3. **The Minimal Circuit:** What are the *minimal circuit components* needed to model acquisition and extinction in the LA? Why can't we model this with just excitatory Principal Neurons (PNs)?
# 4. **The Timing Logic:** If **inhibitory onset** (PV/SOM) is advanced (occurs earlier), what happens to the PN **Peak** and **Latency** during tone‑evoked responses? Explain the biophysical mechanism.
# 5. **Acquisition vs. Expression:** Distinguish between *acquisition* (the learning process) and *expression* (the behavioral readout). Give an example from your simulation where expression changed without the circuit "forgetting" the memory.
# 6. **The Gatekeeper Role:** Why is **timed inhibition** central to the CS‑evoked output after learning? Relate your answer to your observations of the **Population Trace**.
# 7. **Parameter Sensitivity:** If **PN↔PN recurrent gain** increases while inhibition stays fixed, what happens to the stability of the fear response? At what point does the circuit become "unstable"?
# 8. **Engineering Trade-off:** Identify one limitation of using a **12‑cell teaching model** compared to the 1,000+ cell models found in research—and one specific advantage it offers for a student’s first time exploring these concepts.
# 9. **Extinction Dynamics:** In this model, is extinction caused by "unlearning" the CS-US connection or by the recruitment of new inhibitory control? Cite your observations from the **Extinction Phase** raster.
# 10. **Systems Synthesis:** Summarize how Set 9 links **Mechanism → Plasticity → Circuit Logic → Behavior** using the same "Analysis Kit" (Baseline, Peak, Latency) you have used since Set A.
