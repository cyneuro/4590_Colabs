# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cyneuro/4590_Colabs/blob/main/1_Math_Refresher.ipynb)

# %% [markdown]
# # Set 1 — Getting Started: Math Refresher
# **Author: Neural Engineering Laboratory, University of Missouri - Gregory Glickert, Khuram Choudhry, Ziao Chen, Satish S. Nair**
#
# ---
# ### Overview
# This module refreshes the minimum math needed for the rest of this course: differentiation, integration, how they combine into a differential equation, and how to solve one numerically. You will reuse these ideas — especially the **time constant** — starting in Set 2.
#
# ### A Note on This Notebook
# **This completed, filled-in notebook is the lab deliverable.** As you work through it you will (1) use AI for concept explanations where indicated, (2) do certain calculations **by hand, without AI** — marked with a 🚫 banner, and (3) add your own cells (notes, extra experiments, questions) wherever useful. A good submission has your own explanations in it, not just filled blanks — treat it as a personal reference you'd be glad to reuse or teach from later.
#
# *Note: this module makes deliberate, explicit use of an AI assistant (Gemini, built into Colab) as a self-learning tool for concept explanations. Sets 2 onward do not use AI in this way — this is specific to a self-paced refresher.*

# %% [markdown]
# ---
# ### 📋 Before You Begin: How This Module Is Graded
# This module's submission and its companion quiz are weighted **equally**. The quiz is not a formality — it's specifically designed to check whether the understanding behind your submission is actually yours.
#
# Pasting an AI's derivation, or a classmate's, can get this notebook looking complete. It will not get you through the quiz, because the quiz asks you to apply the same reasoning to a **new** number or scenario you haven't seen before — something only actually understanding the material lets you do.
#
# The **design problems** you'll find right after each hand-work section below exist for exactly this reason: they're low-stakes practice at doing this yourself, with the answer revealed immediately so you can check your own reasoning before it counts for anything. Treat them as your actual quiz prep, not extra busywork.
#
# ---

# %% [markdown]
# ## 1.0 — What Is Colab?
# A Colab notebook is made of cells: **markdown cells** (text, like this one) and **code cells** (runnable Python — click and press Shift+Enter). Cells run top to bottom and remember earlier results.
#
# You'll also see a **sparkle (✨) icon** near the code editor — that's **Gemini**, built into Colab. We use it deliberately at a few points below, always clearly marked.
#
# **Activity 1.0 — Teach yourself what Colab is.** Ask Gemini: *"Explain what Google Colab is and how notebooks work, as if teaching a complete beginner who has never coded before."* Paste the response below, then explain it back in your own words — if you can explain it simply, you've understood it.
#
# *Your Answer Here (paste Gemini's response, then your own summary):*

# %% [markdown]
# ## 1.1 — Differentiation, Refreshed
# ### A straight line, first
# A linear equation has the form **y = mx + b** (*m* = slope, *b* = y-intercept).
#
# **Example:** the line y = 2x + 1. What is its slope? Its y-intercept? What do those two numbers mean, in terms of how y changes as x changes?

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-5, 5, 0.5)
m, b = 2, 1
y = m*x + b

plt.figure(figsize=(6,4))
plt.plot(x, y)
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid()
plt.xlabel('x'); plt.ylabel('y')
plt.title(f'y = {m}x + {b}')
plt.show()

# %% [markdown]
# **Activity 1.1a — Teach yourself the derivative.** Ask Gemini: *"Explain the concept of differentiation using simple, non-technical examples, and help me relearn the fundamentals — assume I haven't touched calculus in years and I'm coming from a biology/psychology background, not engineering."* Paste the response, then summarize in your own words: what does a derivative measure?
#
# *Your Answer Here:*

# %% [markdown]
# ### 🚫 Hand-Work — No AI for This Part
# The **derivative** of f(x) at a point is the slope of the tangent line there (limit definition):
# $$f'(x) = \lim_{\Delta x \to 0} \frac{f(x+\Delta x) - f(x)}{\Delta x}$$
# Every differentiation formula you'll ever use comes from this one definition.
#
# **Worked example — f(x) = 2x:**
# $$f'(x) = \lim_{\Delta x \to 0} \frac{2(x+\Delta x) - 2x}{\Delta x} = \lim_{\Delta x \to 0} \frac{2\Delta x}{\Delta x} = 2$$
#
# **Activity 1.1b — Your turn, by hand.** Using the same limit definition, work out $f'(x)$ for $f(x) = x^2$. Show every step (hint: expand $(x+\Delta x)^2$ first).
#
# *Your Answer Here (show your derivation step by step):*

# %% [markdown]
# ### 🎯 Design Problem — Put Differentiation to Use
# This time, you're not just differentiating a formula you're handed — you're deciding what the formula should even *be*, from a real scenario.
#
# **Scenario:** A ball is thrown upward. Its height above the ground is $h(t) = 20t - 5t^2$ meters, where $t$ is in seconds. What is the ball's **velocity** at $t=1$ second?
#
# **By hand, on paper:** figure out what quantity you actually need (hint: velocity is a rate of change of position — which derivative rule from above applies?), compute it, and evaluate at $t=1$.
#
# A) $v(1) = 20$ m/s   B) $v(1) = 10$ m/s   C) $v(1) = -10$ m/s   D) $v(1) = 15$ m/s
#
# *Work it out before revealing the answer below.*

# %% [markdown]
# **Answer: B) $v(1) = 10$ m/s.**
#
# $\dot h(t) = 20 - 10t$ (differentiating each term). At $t=1$: $\dot h(1) = 20-10(1) = 10$ m/s.
#
# The actual skill here wasn't the differentiation itself — you'd already done harder ones above. It was recognizing that "velocity" *means* "derivative of position," without being told that directly. That translation step is what the quiz will actually test.

# %%
# Verify your hand answer here — but do the hand derivation FIRST.
import numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-5, 5, 0.1)
y = x**2
dy_dx_analytical = 2*x   # <-- does this match what you derived by hand?

plt.figure(figsize=(6,4))
plt.plot(x, y, label='f(x) = x²')
plt.plot(x, dy_dx_analytical, label="f'(x) = 2x")
plt.legend(); plt.grid()
plt.show()

# %% [markdown]
# ## 1.2 — Integration, Refreshed
# If a derivative is a rate of change, an **integral** is the reverse: given a rate of change, find the total accumulated change. Geometrically, $\int_a^b f(x)\,dx$ is the **signed area** between $f(x)$ and the x-axis, from $a$ to $b$.
#
# **Activity 1.2a — Teach yourself integration.** Ask Gemini: *"Explain integration as the reverse of differentiation, using simple examples with constant or linear functions — I want the intuition of 'area under a curve,' not a long list of formulas."* Paste the response, then summarize: what does an integral measure?
#
# *Your Answer Here:*

# %% [markdown]
# ### 🚫 Hand-Work — No AI for This Part
# **Worked example:** if $\dot V = 20$ (a constant rate of change), then $V(t) = V(0) + 20t$ — the area under a constant $\dot V$ vs. $t$ curve is just a rectangle.
#
# **Activity 1.2b — Your turn, by hand.** Sketch $\dot V = 20$ vs. time, and $V(t)$ vs. time (use $V(0)=0$). Then work out $V(t)$ if $\dot V = 2t$ instead — this 'rectangle' becomes a triangle. Show your reasoning.
#
# *Your Answer Here (describe your sketches and reasoning for both cases; you may attach a photo of a paper sketch instead):*

# %% [markdown]
# ### 🎯 Design Problem — Put Integration to Use
# Same idea as before, now for integration: translate a real scenario into the right setup yourself.
#
# **Scenario A (the "rectangle" case):** A car travels at a constant 70 mph. How far has it gone after 3 hours?
#
# **By hand:** set up the integral, evaluate it.
#
# A) 210 miles   B) 70 miles   C) 23.3 miles   D) 3 miles
#
# **Scenario B (the "triangle" case):** Water enters a tank at a *linearly increasing* rate, $r(t) = 4t$ liters/minute (starting from 0). How many liters are in the tank after 5 minutes?
#
# **By hand:** sketch $r(t)$ vs. $t$ first — what shape is the area under it? — then compute.
#
# A) 20 L   B) 50 L   C) 100 L   D) 10 L
#
# *Work both out before revealing the answers below.*

# %% [markdown]
# **Scenario A answer: A) 210 miles.** Distance $= \int_0^3 70\,dt = 70t\Big|_0^3 = 210$ miles — a rectangle, because the rate is constant.
#
# **Scenario B answer: B) 50 L.** Distance $= \int_0^5 4t\,dt = 2t^2\Big|_0^5 = 2(25) = 50$ liters — a triangle, because the rate itself is growing linearly, so the "area" traced out has a sloped top edge rather than a flat one.
#
# Notice this is exactly the rectangle-vs-triangle distinction from the Knowledge Bank (Category C) — except now you derived *why* it's a triangle from a real scenario, instead of being told the shape and asked to explain it after the fact.

# %% [markdown]
# ## 1.3 — From a General Law to a Differential Equation
# You can now differentiate and integrate. Here's why that matters: **almost every model in this course is a differential equation** — an equation containing a derivative.
#
# **Activity 1.3a — Ask AI first:**
#
# > *"Why can very different real-world systems — from biology to electrical engineering — often be described by the exact same first-order differential equation? Can you give me one example from biology and one from engineering that share this same underlying pattern?"*
#
# Paste the response, then compare it to the general pattern below — did AI's examples resemble the two we're about to walk through?
#
# *Your Answer Here:*
#
# A **first-order** DE contains only first derivatives ($\dot y$, not $\ddot y$). We'll use a general pattern covering a wide range of systems:
# $$a_1 \dot y(t) + a_2\, y(t) = a_3\, u(t), \quad y(0) = y_0$$
# which can always be rewritten in **standard form** by dividing through by $a_2$:
# $$\tau \dot y(t) + y(t) = K\, u(t), \quad y(0) = y_0$$
# where $\tau = a_1/a_2$ is the **time constant** (how fast the system responds) and $K = a_3/a_2$ is the **gain** (where it settles). $u(t)$ is the driving input, often a constant.
#
# Here are two very different-looking systems that are secretly the same math.

# %% [markdown]
# ### Example 1 — A Neuron as an RC Circuit
# **Activity 1.3b — Ask AI:**
#
# > *"Explain, conceptually, how a passive patch of neuron membrane — modeled as a resistor and capacitor in parallel, with a battery for the resting potential — gives rise to a first-order differential equation for voltage over time."*
#
# Paste the response, then compare it to the actual equation:
#
# A passive patch of membrane behaves like a resistor ($R_m$) and capacitor ($C_m$) in parallel, with a battery ($E_m$, the resting/Nernst potential of the leak channel). Current conservation gives:
# $$C_m \frac{dV}{dt} = -\frac{(V - E_m)}{R_m} + I$$
#
# **Activity 1.3c.** Match this to the general form above — what are $a_1$, $a_2$, $a_3$, and $u(t)$? What do $\tau$ and $K$ mean physically for a neuron? (You'll work with exactly this equation starting in **Set 3**.)
#
# *Your Answer Here:*

# %% [markdown]
# ### Example 2 — Population Growth (Ecology)
# **Activity 1.3d — Ask AI:**
#
# > *"Explain, conceptually, how a simple population-growth model — where birth and death rates are each proportional to the current population — leads to a first-order differential equation. Is this the same equation form as an RC circuit?"*
#
# Paste the response, then compare it to the actual model:
#
# A simple population-growth model (Malthus, 1798) assumes births and deaths are each proportional to the current population $N$:
# $$\dot N = \beta N - \delta N$$
# where $\beta, \delta$ are birth/death rate constants — also first-order, but with no separate input term $u(t)$.
#
# **Activity 1.3e.** Is this an example of the general standard form $\tau \dot y + y = Ku(t)$? Why or why not — what would $u(t)$ need to be for it to fit? (Conceptual — no calculation needed.)
#
# *Your Answer Here:*

# %% [markdown]
# ## 1.4 — Solving It Numerically, By Hand and In Code
# We won't solve this algebraically. Instead, we'll do what a computer does: use the derivative's own definition to take small, repeated steps.
#
# ### 🚫 Deriving the Update Rule — No AI for This Part
# Start from: $\frac{dy}{dt} \approx \frac{y(t+\Delta t) - y(t)}{\Delta t}$.
#
# **Activity 1.4a.** Rearrange this to solve for $y(t+\Delta t)$ in terms of $y(t)$, $\dot y$, and $\Delta t$. This is **Euler's method** — the idea behind numerically solving almost any differential equation.
#
# *Your Answer Here (your derived update rule, $y(t+\Delta t) = \;?$):*

# %% [markdown]
# ### The Running Example
# We'll use the neuron-style equation from 1.3, in standard form, with real numbers:
# $$\dot y + 3y = -30, \qquad y(0) = -60$$
# (think of $y$ as membrane potential $V$ in mV, $t$ in ms — a passive membrane getting a constant current injection at $t=0$).
#
# **Activity 1.4b.** Rewrite this in standard form to find $\tau$ and $K$ by hand (same method as 1.3).
#
# *Your Answer Here:*

# %% [markdown]
# ### 🚫 Coding the Euler Loop Yourself — No AI for This Part
# This is the one piece of code in this notebook you should not ask AI to write. Fill in the blanks using the update rule you derived. Every model later in this course (LIF, Hodgkin-Huxley, synapses, the amygdala circuit) is solved exactly this way — just with more equations running at once.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# --- the equation: y_dot + 3*y = -30, i.e., a1=1, a2=3, a3=-30 ---
a1, a2, a3 = 1, 3, -30
y0 = -60          # initial condition

tau = ______      # <-- fill in, from Activity 1.4b
K   = ______      # <-- fill in

dt = 0.1          # time step (ms)
t_start, t_stop = 0, 2

t = np.arange(t_start, t_stop, dt)
y = np.empty(t.shape)
y[0] = y0

for i in range(1, len(t)):
    dydt = ______________________   # <-- fill in: RHS of tau*y_dot + y = K, solved for y_dot
    y[i] = ______________________   # <-- fill in: your Euler update rule from 1.4a

plt.figure(figsize=(7,5))
plt.plot(t, y, '.-')
plt.xlabel('t (ms)'); plt.ylabel('y (mV)')
plt.title('Numerical (Euler) solution')
plt.grid()
plt.show()

# %% [markdown]
# **Reflection — time constant.** The time constant $\tau$ is the time to reach **63.2%** of the total change from $y(0)$. Estimate $\tau$ directly from your plot. Does it match your hand calculation from 1.4b?
#
# *Your Answer Here:*

# %% [markdown]
# ## 1.5 — Embedded Playground
# Use your working Euler loop to explore. Copy it into the cells below and modify as instructed.
#
# **Task 1 — Step size and accuracy.** Predict first: what happens to your numerical curve if $\Delta t$ gets much bigger (e.g., $\Delta t = 1$ or $2$ instead of $0.1$)? Write your prediction, then test it by re-running with all three and plotting them together.
#
# *Your Prediction (before running anything):*

# %%
# Task 1 — copy your Euler loop here, re-run with dt = 0.1, 1, and 2, and plot all three together.

# %% [markdown]
# *Your Answer Here (what happened — did it match your prediction? where does the curve stop looking believable?):*

# %% [markdown]
# **Task 2 — Two systems, two speeds.** Set up a second system with a different $\tau$ (change $a_2$). Predict first: does a larger or smaller $\tau$ reach steady state faster? Then plot both curves together to check.
#
# *Your Prediction:*

# %%
# Task 2 — set up a second system with a different tau, plot both curves together.

# %% [markdown]
# *Your Answer Here:*

# %% [markdown]
# **Task 3 — Ask Gemini, then test it yourself.** The one place in this notebook where you use Gemini for a real prediction, not just an explanation.
#
# Ask Gemini: *"In Euler's method for solving a differential equation, what happens numerically if the time step is larger than the system's time constant? Explain conceptually, without heavy math."* Paste the answer, then check whether it matches what you actually observed in Task 1.
#
# *Your Answer Here (Gemini's explanation, then whether your own results supported or contradicted it):*

# %% [markdown]
# ## Software Lab 1 Assignment (Homework — This Is What Quizzes and Exams Will Look Like)
# *(Adapted from the original Getting Started with Math handout — WolframAlpha/MATLAB references replaced with Python.)*
#
# **Complete the following directly in this notebook. Items 2, 3, and 4 are hand-work — no AI.**
#
# 1. Review all examples and activities above — make sure every code cell has been run at least once.
# 2. **By hand**, using the limit definition of the derivative (1.1), calculate the derivative of each from first principles, showing every step: $f(y) = 1/y$; $p(m) = m^2$; $r(w) = 20w$.
# 3. **By hand**, using the definition of area under the curve (1.2), calculate the integral of each: $f(y) = 1$; $p(m) = 2m$; $r(w) = w^2$.
# 4. **Worksheet 4(i)–(iv):**
#    - (i) Sketch $y = t^2$ for $t \in [-2, 2]$. **By hand**, calculate $dy/dt$ analytically (limit definition) at $t = 0, 1, 2$.
#    - (ii) Calculate the derivative at the same points using the Euler (rise/run) approximation. Compare to (i).
#    - (iii) Plot the numerical derivative of $y=t^2$ from $t=-2$ to $2$ (Python is fine for the plotting; the calculation logic should be yours).
#    - (iv) Reverse the problem: given $dy/dt = 2t$, use the numerical method from 1.4 to calculate $y(t)$, plot it, and check against your analytical answer from (i)/(iii). Discuss any differences.
# 5. **Quick drill — standard form.** By hand, convert each to standard form ($\tau\dot y + y = Ku(t)$) and state $\tau$ and $K$ for each: (a) $2\dot y + 8y = 40$; (b) $5\dot y + y = -15$; (c) $0.5\dot y + 2y = 10$.
# 6. Solve $\dot V + 4V = -30, \; V(0) = -60$ using **two approaches**:
#    - (i) **By hand**, using the numerical (Euler) integration technique — a few steps is enough.
#    - (ii) **In Python**, implement the same numerical integration using **two noticeably different $\Delta t$ values**, and plot both to show the effect on accuracy.
#    - (iii) From your plot, estimate the **time constant**, and confirm it matches $\tau = a_1/a_2$ from the equation directly.
#
# *Optional, not required: if curious whether Python can solve this kind of equation symbolically, look up the `sympy` library (`sympy.dsolve`) on your own.*

# %%
# Item 2 — Python verification (after your hand derivations above):

# %%
# Item 3 — Python verification:

# %%
# Item 4 — worksheet 4(i)-(iv), Python plots:

# %%
# Item 5 — verify your by-hand standard-form conversions:
for a1, a2, a3 in [(2,8,40), (5,1,-15), (0.5,2,10)]:
    tau, K = a1/a2, a3/a2
    print(f'a1={a1}, a2={a2}, a3={a3}  ->  tau={tau}, K={K}')

# %%
# Item 6 — Euler solution for V_dot + 4V = -30, with two different dt values:

# %% [markdown]
# ### 🎯 Your Turn — Design Two Questions, Not Just Answer Them
# Pick any concept from this Set. Create **two** short questions of your own — one of each type:
#
# **1. An Analysis-type question:** present a scenario, plot, or result, and ask the reader to interpret *why* something happened or what it implies.
#
# **2. A Design-type question:** ask the reader *how* to achieve a specific target outcome, or what change would produce a given effect.
#
# For each: include a brief setup, 2–4 possible answers, the correct answer, and a short explanation of why. No required format or topic beyond that — design both however makes sense to you. If your questions would genuinely catch someone who only skimmed this Set, you've demonstrated real understanding.
#
# *Your Analysis-type question, answers, and explanation here:*
#
# *Your Design-type question, answers, and explanation here:*

# %% [markdown]
# ---
# ## Knowledge Bank — Set 1: Math Refresher
#
# **This is the outcome of this module.** Quizzes, the midterm, and the final draw directly from these questions — know them well. For anything you're unsure about, use an AI assistant to research it, and add what you find as your own notes right in this notebook. That documentation is part of your deliverable, same as everything else here.
#
# ### A. Colab & Self-Learning Basics
# 1. What are the two main types of cells in a Colab notebook, and what does each contain?
# 2. What is the sparkle icon in Colab, and what does it let you do?
# 3. Why does this notebook explicitly mark certain steps "No AI"?
# 4. What does it mean for "the completed, filled-in notebook" to be the lab deliverable?
# 5. In what order do cells in a notebook execute, and why does that order matter?
#
# ### B. Differentiation
# 6. What does a derivative measure, geometrically?
# 7. State the limit definition of the derivative.
# 8. Derive the derivative of $f(x) = 2x$ from the limit definition, showing every step.
# 9. Derive the derivative of $f(x) = x^2$ from the limit definition, showing every step.
# 10. Why must $\Delta x$ approach 0, rather than being canceled early, in the limit definition?
# 11. If $f(x)$ is a straight line, what is true about $f'(x)$ everywhere along it?
#
# ### C. Integration
# 12. What does a definite integral measure, geometrically?
# 13. If $\dot V = 20$ (a constant) and $V(0)=0$, what is $V(t)$?
# 14. If $\dot V = 2t$ instead, what shape does the area under the curve take, and what is $V(t)$?
# 15. In your own words, how is integration the reverse of differentiation?
# 16. Why is the area under a linearly increasing rate a triangle rather than a rectangle?
#
# ### D. Differential Equations & the General First-Order Model
# 17. Write the general first-order differential equation form, using $a_1, a_2, a_3, u(t)$.
# 18. Write the standard form using $\tau$ and $K$, and explain what each represents physically.
# 19. How do you convert from the general form to standard form?
# 20. For a passive neuron membrane, what are $a_1$, $a_2$, $a_3$, and $u(t)$, in terms of $C_m$, $R_m$, $E_m$, and $I$?
# 21. What is the time constant $\tau$ for the neuron RC-circuit example, in terms of $R_m$ and $C_m$?
# 22. Is the population-growth equation $\dot N = \beta N - \delta N$ in standard form $\tau\dot y + y = Ku(t)$? Explain why or why not.
# 23. Give one real-world example (not from this notebook) that could plausibly follow this same first-order pattern, and identify what plays the role of $y$, $\tau$, and $K$.
#
# ### E. Euler's Method & Numerical Solutions
# 24. State the approximation, based on the derivative's definition, that Euler's method comes from.
# 25. Derive Euler's update rule: $y(t+\Delta t) = \;?$
# 26. Why do we solve most real differential equations numerically rather than always solving them algebraically?
# 27. For $\dot y + 3y = -30$, $y(0) = -60$, what are $\tau$ and $K$ in standard form?
# 28. Write, from memory, the core line of code that performs one Euler update step.
# 29. Why is coding the Euler loop yourself (rather than asking AI to write it) treated as a "No AI" checkpoint in this notebook?
#
# ### F. Step Size, Stability & Comparing Systems
# 30. In the Embedded Playground, what happened to the numerical solution when $\Delta t$ exceeded the time constant $\tau$?
# 31. Between two systems with different $\tau$ values, which one reaches steady state faster, and why?
# 32. What is the practical trade-off in always choosing a very small $\Delta t$ for a simulation?
# 33. Why is asking an AI to predict a numerical-stability result, then testing it yourself, a good way to check your own understanding?
# 34. Summarize, in one or two sentences, the full chain of ideas from "derivative" to "numerically solving a real neuron model."

# %% [markdown]
# ## References
# * Original handout: *Getting Started with Math* (Computational Neuroscience course materials, University of Missouri; adapted from a variety of web sources).
# * Original handout: *Getting Started with MATLAB* (Computational Neuroscience course materials, University of Missouri).
# * Murray, J. D. (2002). *Mathematical Biology I: An Introduction* (3rd ed.). Springer.
#
# ---
# **What comes next:** Set 2 — Neurobiology Refresher and Onboarding Appendix.
